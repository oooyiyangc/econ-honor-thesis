# %% [markdown]
# # Census Bureau Quarterly Tax Data

# %%
import numpy as np
import pandas as pd
import re

# %%
OCR_DIR = "../../data/raw-data/cb-tax/ocr/"

# %%
df = pd.read_csv(OCR_DIR + "cleaned.txt", delim_whitespace=True)
df
# Out:
#      period   total   state   local property generalsales   fuel  \
# 0   1968-Q4  21,254   9,035  12,219   11,310        3,496  1,424
# 1   1968-Q3  15,971   8,716   7,255    6,253        3,305  1,480
# 2   1968-Q2  19,217  11,206   8,011    7,093        3,265  1,331
# 3   1968-Q1  16,752   9,983   6,769    6,001        3,164  1,255
# 4   1967-Q4  18,726   7,868  10,858   10,023        2,924  1,308
# 5   1967-Q3  14,193   7,356   6,837    5,984        2,973  1,332
# 6   1967-Q2  16,496   9,450   7,046    6,249        2,606  1,249
# 7   1967-Q1  14,827   8,679   6,148    5,430        2,638  1,133
# 8   1966-Q4  16,775   6,895   9,880   9,121.        2,505  1,225
# 9   1966-Q3  12,624   6,808   5,e16    5,090        2,396  1,278
# 10  1966-Q2  15,784   8,992   6,792    6,012        2,524  1,178
# 11  1966-Q1  13,754   8,186   5,568    4,997        2,454  1,094
# 12  1965-Q4  15,823   6,411   9,412    8,802        2,342  1,160
# ...
